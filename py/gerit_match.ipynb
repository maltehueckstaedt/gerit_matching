# %% [markdown]
# <a href="https://colab.research.google.com/github/maltehueckstaedt/gerit_matching/blob/main/gerit_match.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GERIT PRE-Matching mit OpenAI-Embeddings
#
# Im folgenden wird ein Notebook entworfen, dass das derzeitige Matching der HEX der Daten mit GERIT-Organisationen erleichtern soll. Im Derzeitigen Stand geht folgendermaßen vor:
#
# Es wird von einem klassischen Cleaning der Organisations-Variable, wie sie aus den Scrapiung kommt, abgesehen, weil es im vergleich zum folgenden Vorgehen (und angesichts des Umstandes, dass wir ja die *wahren* Organisationennamen schon kennen) uneffizient und die Gefahr von Artfacten höher erscheint.
#
# Statt eines klassischen Cleanings mit Hilfe von LLMs wird eine Funktion implementiert,die nach Entsprechungen in der Liste der GERIT-Organisationen. Dafür werden mit OpenAI Embeddings Vektor-Repräsentationen aller GERIT-Namen erstellt. Ein *„Retriever“* durchsucht diese Vektoren, um die besten Übereinstimmungen zu einem gegebenen Namen (also den Organisationsnamen aus dem Scraping) zu finden. Das Modell kann z. B. erkennen, dass „*Institut für Biologie*“ und „*Department Biologie*“ wahrscheinlich dasselbe meinen.
#
# Für jede Organisation wird überprüft, ob es eine exakte Übereinstimmung gibt. Falls ja, wird der offizielle GERIT-Name übernommen. Falls keine exakte Übereinstimmung gefunden wird, kommt ein Fuzzy Matching zum Einsatz, bei dem ein kosinusbasierter Score berechnet wird (0 = völlig unterschiedliche Begriffe, 1 = perfekte Übereinstimmung). Ist der Score hoch genug (aktuell: > 0.5), wird der bestpassende GERIT-Treffer übernommen. Falls keine passende Entsprechung gefunden wird, bleibt der Wert NA.
#
# Vorteile: Die Funktion spart Zeit – es werden derzeit 20.000 Zeilen und 250 unique Werte in etwa 1,5 Minuten umcodiert. Zudem ist kein manuelles Coding oder eine zusätzliche Aufbereitung der Organisationsvariablen nötig. Mit dem Score-Cutoff kann weiterhin die Konservativität des tools gesteuert werden.
#
# Nachteile: Die Qualität der Zuordnung muss geprüft werden, und es bleibt die Frage, wie sich das neue >>Cleaning>> oder Vor-Matching auf nachfolgende Analysen auswirkt.
#
# ## Programmierung der Funktion
#
# ### Einrichtung Arbeitspfad
#
# In einem ersten Schritt überprüfen wir unseren derzeitgen Arbeitspfad (in dem Fall das wir lokal arbeiten).

# %%
import os
os.getcwd()
os.chdir("c:/Users/Hueck/OneDrive/Dokumente/GitHub/gerit_matching")

# %% [markdown]
# ### Laden und checke der Daten
#
# Wir laden einerseits testweise der Daten (inkl. der Organisationsvariable) der HHU, andererseits die GERIT-Daten der hhu.

# %%
import pandas as pd
import pyreadr

# df_scraped = pd.read_csv("data\hhu_db_raw.csv")
# #df_scraped = df_scraped.sample(n=200, random_state=42)
# Einrichtung = pd.read_excel("data/Einrichtung.xlsx")

result = pyreadr.read_r("data/df_gerit.rds")
df = list(result.values())[0]  
df_gerit = df.loc[df["is_LUF_unique"] == "ja", ["Einrichtung"]]  # DataFrame statt Series

result = pyreadr.read_r("data/df_scraped.rds")
df = list(result.values())[0]  
df_scraped = df.loc[df["organisation_type_for_matching"] != "combinations", ["organisation_names_for_matching_back"]]  # DataFrame statt Series

# %%
df_gerit["Einrichtung"]
# Out:
# 0      Arbeitsgemeinschaft Elektrochemischer Forschun...
# 1      Biologisch-Medizinisches Forschungszentrum (BMFZ)
# 2               Genomics und Transcriptomics Labor (GTL)
# 3                  Molecular Proteomics Laboratory (MPL)
# 4                      Center for Advanced Imaging (CAi)
#                              ...
# 319    Lehrstuhl für BWL, insbes. Arbeit, Personal un...
# 320    Lehrstuhl für BWL, insbesondere Betriebswirtsc...
# 321    Lehrstuhl für BWL, insbesondere Finanzdienstle...
# 322            Lehrstuhl für BWL, insbesondere Marketing
# 323    Lehrstuhl für Volkswirtschaft, insb. Monetäre ...
# Name: Einrichtung, Length: 297, dtype: object

# %% [markdown]
# Wir zeigen in folgenden die Spaltennamen, den Typ der Variable `organisation_names_for_matching_back` und ihre uniquen Werte an.

# %%
df_scraped.columns
print(df_scraped["organisation_names_for_matching_back"].dtype)
print(df_scraped["organisation_names_for_matching_back"].unique())
# Out:
# object
# ['Studiendekanat Medizinische Fakultät' 'Juristische Fakultät'
#  'Sprachenzentrum' 'Wissenschaftliche Einrichtung Mathematisches Institut'
#  'Wissenschaftliche Einrichtung Informatik' 'Institut für Philosophie'
#  'Wissenschaftliche Einrichtung Physik' 'Institut für Romanistik'
#  'Institut für Medien- und Kulturwissenschaft'
#  'Institut für Kunstgeschichte' 'Institut für Experimentelle Psychologie'
#  'Department Biologie' 'Institut für Modernes Japan'
#  'Institut für Linguistik' 'Wirtschaftswissenschaftliche Fakultät'
#  'Deutsch als Fremdsprache'
#  'Institut für Pharmazeutische und Medizinische Chemie'
#  'Institut für Pharmazeutische Technologie'
#  'Diagnostische und Interventionelle Radiologie' 'Medizinische Fakultät'
#  'Institut für Molekulare Medizin I'
#  'Institut für Organische Chemie und Makromolekulare Chemie'
#  'Abt. III: Deutsche Sprache und Literatur des Mittelalters'
#  'Zentrum für Medizinische Mikrobiologie, Krankenhaushygiene und Virologie'
#  'Abt. II: Neuere Dt. Literatur - Lehrstuhl Prof. Dörr'
#  'Zentrum für Kinder- und Jugendmedizin - Kinderklinik'
#  'Institut für Geschichtswissenschaften'
#  'Abt. I: Germanistische Sprachwissenschaft'
#  'Institut für Klassische Philologie'
#  'Institut für Pharmazeutische Biologie' 'CEPLAS' 'Frauenklinik'
#  'Career Service' 'Institut für Anorganische Chemie und Strukturchemie'
#  'Musikwissenschaftliches Institut der Robert-Schumann-Hochschule Düsseldorf'
#  'Abteilung für Kommunikations- und Medienwissenschaft'
#  'Institut für Anglistik und Amerikanistik'
#  'Abteilung für Politikwissenschaft' 'Institut für Jüdische Studien'
#  'Institut für Biochemie' 'Molekulare Evolution' 'philGRAD'
#  'Abt. II: Neuere Dt. Literatur - Lehrstuhl Prof. Oesterhelt'
#  'Klinik und Poliklinik für Psychiatrie und Psychotherapie der Heinrich-Heine-Universität Düsseldorf - LVR-Klinikum Düsseldorf'
#  'Abteilung für Soziologie' 'Zentrum für Pharmakologie und Toxikologie'
#  'Klinik für Urologie' 'Abteilung für Informationswissenschaft'
#  'Fakultäten' 'Institut für Theoretische Chemie und Computerchemie'
#  'Poliklinik für Zahnerhaltung, Parodontologie und Endodontologie'
#  'Biochemie der Pflanzen'
#  'Abteilung für Jiddische Kultur, Sprache und Literatur' 'Augenklinik'
#  'D 1.1 Studierendenservice'
#  'Anglistik I: Medieval Literatures and Historical Linguistics'
#  'Philosophische Fakultät' 'Mikrobiologie' 'Zentrum für Physiologie'
#  'Poliklinik für Zahnärztliche Chirurgie und Aufnahme'
#  'Institut für Physikalische Chemie und Elektrochemie'
#  'Klinik für Anästhesiologie' 'Institut für Sozialwissenschaften'
#  'Wissenschaftliche Einrichtung Chemie'
#  'Klinische Pharmazie und Pharmakotherapie' 'Neurologische Klinik'
#  'Institut für Anatomie I' 'Botanik' 'Institut für Allgemeinmedizin'
#  'Institut für Bioorganische Chemie'
#  'Poliklinik für Zahnärztliche Prothetik'
#  'Universitäts- und Landesbibliothek' 'Abteilung für Jüdische Studien'
#  'Anglistik V - Anglophone Literaturen/Literaturübersetzen' 'Zellbiologie'
#  'Genetik' 'Biochemische Pflanzenphysiologie'
#  'Mathematisch-Naturwissenschaftliche Fakultät'
#  'Klinik für Gastroenterologie, Hepatologie und Infektiologie'
#  'Abteilung II Neuere Geschichte' 'European Studies'
#  'Institut für Cytopathologie' 'Gleichstellung' 'Mikrobielle Zellbiologie'
#  'Funktionelle Zellmorphologie' 'Wissenschaftliche Einrichtung Pharmazie'
#  'Institut für Klinische Neurowissenschaften und Medizinische Psychologie'
#  'Abteilung VI Neuere Landesgeschichte u. Neueste Geschichte'
#  'Abteilung V Geschichte und Kulturen Osteuropas'
#  'Entwicklungs- und Molekularbiologie der Pflanzen'
#  'Institut für Systemische Neurowissenschaften'
#  'Abteilung für Allgemeine Sprachwissenschaft'
#  'Hals-, Nasen- und Ohrenklinik'
#  'Klinisches Institut für Psychosomatische Medizin und Psychotherapie'
#  'Molekulare Ökophysiologie der Pflanzen'
#  'Abteilung für Bildungsforschung und Bildungsmanagement'
#  'Institut für Germanistik' 'Molekulare Enzymtechnologie'
#  'Institut für Geschichte, Theorie und Ethik der Medizin'
#  'Institut für Transplantationsdiagnostik und Zelltherapeutika'
#  'Physikalische Biologie' 'Evolutionsgenetik' 'Populationsgenetik'
#  'Politikwissenschaft IV'
#  'Funktionelle Genomforschung der Mikroorganismen'
#  'C. & O. Vogt-Institut für Hirnforschung' 'IKM-Services'
#  'Quantitative Genetik und Genomik der Pflanzen CEPLAS'
#  'Abt. II: Neuere Dt. Literatur - Lehrstuhl Prof. Nebrig'
#  'Prorektorat für Hochschulmanagement und Internationales'
#  'Stoffwechselphysiologie' 'Neurobiologie'
#  'Zell- und Interaktionsbiologie CEPLAS'
#  'Institut für Bio- und Geowissenschaften, IBG-1, Forschungszentrum Jülich GmbH'
#  'Lehrstuhl Organische Chemie und Makromolekulare Chemie II'
#  'Anglistik VI - Comparative Literature' 'Abteilung III Alte Geschichte'
#  'Abteilung VIII Geschichte der Frühen Neuzeit'
#  'Zoologie/Organismische Interaktionen'
#  'Institut für Biochemie und Molekularbiologie I'
#  'Nuklearmedizinische Klinik' 'Anglistik II: American Studies'
#  'Pflanzengenetik CEPLAS' 'Physikalische Chemie u. Elektrochemie I'
#  'Zentralinstitut für Klinische Chemie u. Laboratoriumsdiagnostik'
#  'Neurochirugische Klinik' 'Entwicklungsgenetik'
#  'Mathematische Modellierung biologischer Systeme'
#  'Institut für Toxikologie' 'Anorganische Chemie u. Strukturchemie II'
#  'Physikalische Chemie u. Elektrochemie II' 'Institut für Anatomie II'
#  'Zentrale Einrichtung für Tierforschung und wiss. Tierschutzaufgaben'
#  'Institut für Rechtsmedizin'
#  'Institut für Bio- und Geowissenschaften, IBG-2: Pflanzenwissenschaften'
#  'Politikwissenschaft II' 'Philosophische Fakultät allgemein'
#  'Anglistik IV: Modern English Literature'
#  'HeiCAD Heine Center of Artificial Intelligence and Data Science'
#  'Abt. IV: Theorie und Praxis (Mündlichkeit)'
#  'Abteilung I Mittelalterliche Geschichte'
#  'Biomolekulare Festkörper-NMR-Spektroskopie'
#  'Poliklinik für Kieferorthopädie' 'Politikwissenschaft I'
#  'Molekulare Physiologie' 'Anorganische Chemie u. Strukturchemie I'
#  'Physikalische Grundpraktika' 'Lehrstuhl Festkörperphysik'
#  'Institut für Medizinische Soziologie'
#  'Institut für Herz- und Kreislaufphysiologie'
#  'Institut für medizinische Biometrie und Bioinformatik'
#  'Abteilung für Computerlinguistik' 'Center for Enterpreneurship (CEDUS)'
#  'Synthetische Biologie' 'Studium Universale' 'Biological Data Science'
#  'Dekanat Medizinische Fakultät'
#  'Zentrum für Zahn-, Mund- und Kieferheilkunde - Westdeutsche Kieferklinik'
#  'Institut für Pharmakologie und Klinische Pharmakologie'
#  'Lehrstuhl für Organische Chemie I'
#  'Klinik für Mund-, Kiefer- und Plastische Gesichtschirurgie'
#  'Selbständiger Funktionsbereich für Phoniatrie und Pädaudiologie'
#  'Institut für Pathologie'
#  'Institut für Klinische Biochemie und Pathobiochemie'
#  'Kommunikations- und Medienwissenschaft IV'
#  'Pflanzliche Zellbiologie und Biotechnologie'
#  'Institut für Physikalische Biologie' 'Institut für Mikrobiologie'
#  'Politikwissenschaft III' 'Institut für Neurobiologie'
#  'KUBUS (Praxis- und Berufsorientierung)'
#  'Klinik für Endokrinologie und Diabetologie'
#  'Dekanatsbüro Phil. Fakultät'
#  'Lehrstuhl für Betriebswirtschaftslehre, insbes. Finanzdienstleistungen'
#  'Lehrstuhl für Betriebswirtschaftslehre, insbes. Arbeit, Personal und Organisation'
#  'Photosyntheseforschung CEPLAS'
#  'Lehrstuhl für Betriebswirtschaftslehre, insbes. Unternehmensprüfung und Controlling'
#  'Anglistik III: English Language and Linguistics'
#  'Abt. I: Germ. Sprachwissenschaft - Professur Prof. Kasper'
#  'Soziologie II' 'Soziologie I' 'Soziologie IV'
#  'Praktikumsbüro - Abteilung Soziologie'
#  'Lehrstuhl für Kolloide und Nanooptik'
#  'Quantitative und Theoretische Biologie CEPLAS' 'Institut für Genetik'
#  'Kommunikations- und Medienwissenschaft II'
#  'Kommunikations- und Medienwissenschaft III'
#  'Lehrstuhl für Volkswirtschaftslehre, insbes. Monetäre Ökonomik'
#  'Zentrum für Biochemie und Molekularbiologie'
#  'Synthetische Mikrobiologie CEPLAS'
#  'Institut für Zoomorphologie, Zellbiologie und Parasitologie'
#  'Institut für Biochemie der Pflanzen' 'Studierendenakademie'
#  'Lehrstuhl für Betriebswirtschaftslehre, insbes. Sustainability Management'
#  'Abt. IV: Theorie und Praxis (Schriftlichkeit)'
#  'DICE (Duesseldorf Institute for Competition Economics)'
#  'Lehrstuhl für Betriebswirtschaftslehre, insbes. Entrepreneurship und Finanzierung'
#  'Volkswirtschaftslehre' 'Lehrstuhl für Statistics and Econometrics'
#  'Kommunikations- und Medienwissenschaft I' 'Gräzistik'
#  'Europäische Expansion' 'Institute und Forschungseinrichtungen'
#  'Institut für Neuropathologie'
#  'Klinik für Allgemein- , Viszeral- und Kinderchirurgie'
#  'Klinik für Hämatologie, Onkologie und klinische Immunologie'
#  'Klinik für Nephrologie'
#  'Klinik für Kardiologie, Pneumologie und Angiologie'
#  'Zentrum für Innere Medizin und Neurologie'
#  'Institut für Biochemie und Molekularbiologie II' 'Hochschulverwaltung'
#  'Institut für Klinische Diabetologie'
#  'Zentrum für Medizinische Psychologie, Soziologie, Statistik und Allgemeinmedizin'
#  'Lehrstuhl Theoretische Physik I'
#  'Arbeitsgruppe Hochauflösende UV-Laserspektroskopie'
#  'Biochemie II: Biotransformation und Biokatalyse'
#  'Entwicklungs- und Molekularbiologie der Tiere' 'SFB 1208 - Biochemie'
#  'Chemische Biologie der Proteinaggregation' 'Sinnesökologie'
#  'Lehrstuhl für Betriebswirtschaftslehre, insbes. Betriebswirtschaftliche Steuerlehre'
#  'Lehrstuhl für Betriebswirtschaftslehre, insbes. Management'
#  'Lehrstuhl für Betriebswirtschaftslehre, insbes. Controlling und Accounting'
#  'Lehrstuhl für Betriebswirtschaftslehre, insbes. Marketing'
#  'Dekanat Wirtschaftswiss. Fakultät'
#  'Externe Mitarbeiter, Lehrende und Gäste der wirtschaftswissenschaftliche Fakultät'
#  'Professur für Volkswirtschaftslehre, insbes. International Economics'
#  'Lehrstuhl für Betriebswirtschaftslehre, insbes. Wirtschaftsprüfung'
#  'Lehrstuhl für Betriebswirtschaftslehre, insbes. Financial Accounting'
#  'Betriebswirtschaftlehre' 'Soziologie III'
#  'Klinik für Kardiovaskuläre Chirurgie'
#  'Zentrum für Operative Medizin I - Chirurgische Klinik und Poliklinik'
#  'Trainingszentrum für ärztliche Fertigkeiten'
#  'Institut für Medizinische Mikrobiologie und Krankenhaushygiene'
#  'Leibniz-Institut für Umweltmedizinische Forschung an der Heinrich-Heine-Universität Düsseldorf gGmbH'
#  'Institut für Arbeitsmedizin und Sozialmedizin'
#  'Lehrstuhl Theoretische Physik IV' 'Lehrstuhl Theoretische Physik III'
#  'Institut für Laser- und Plasmaphysik' 'Lehrstuhl Theoretische Physik II'
#  'Institut für Experimentalphysik - Bereich Prof. Görlitz'
#  'Institut für Theoretische Physik'
#  'Abteilung für Lasermassenspektrometrie'
#  'Arbeitsgruppe Organische Photochemie'
#  'iGRAD - Interdisciplinary Graduate and Research Academy Düsseldorf']

# %% [markdown]
# Unabhängig davon, welcher Typ die Variable `organisation_names_for_matching_back` tatsächlich ist, definieren wandeln wie die Varibale in einen String.
#
# Anschließend erzeugen wir mit `set()` eine leere Menge `unique_values`. `set()` erzeugt eine ungeordnete Sammlung von einzigartigen Elementen. Sets entfernen automatisch doppelte Werte und bieten effiziente Methoden zum Hinzufügen, Entfernen und Überprüfen von Elementen.
#
#
# Wir nehmen dann den Datensatz `df_scraped` und entfernen alle `NaN`. Anschließend wird für jeden verbleibenden Wert die Funktion `apply()` aufgerufen. Innerhalb der Funktion wird der Text jedes Wertes an den Semikolons geteilt, sodass eine Liste von Werten entsteht. Diese Werte werden dann bereinigt, indem führende und nachstehende Leerzeichen entfernt werden und leere oder mit "NA" (unabhängig von der Groß-/Kleinschreibung) markierte Werte ausgeschlossen werden. Alle bereinigten, nicht leeren und nicht "NA"-Werte werden anschließend dem `unique_values`-Set hinzugefügt, wobei nur einzigartige Werte beibehalten werden.
#
# Abschließend wird zur Information die Anzahl uniquer Organisationen sowie die Merkmale ausgegeben.

# %%
import numpy as np

df_scraped["organisation_names_for_matching_back"] = df_scraped["organisation_names_for_matching_back"].astype(str)

unique_values = set()
df_scraped["organisation_names_for_matching_back"].dropna().apply(lambda x: unique_values.update(
    [val.strip() for val in x.split(";") if val.strip() and val.strip().upper() != "NA"]
))

# Ergebnis ausgeben
print(f"Anzahl einzigartiger Werte: {len(unique_values)}")
print(unique_values)
# Out:
# Anzahl einzigartiger Werte: 247
# {'Abt. IV: Theorie und Praxis (Mündlichkeit)', 'Institut für Biochemie der Pflanzen', 'Dekanatsbüro Phil. Fakultät', 'Institut für Geschichte, Theorie und Ethik der Medizin', 'Zentrum für Pharmakologie und Toxikologie', 'Neurobiologie', 'Quantitative und Theoretische Biologie CEPLAS', 'Institut für Neuropathologie', 'Klinik für Anästhesiologie', 'Institut für Klinische Diabetologie', 'Zentrale Einrichtung für Tierforschung und wiss. Tierschutzaufgaben', 'Molekulare Evolution', 'Institut für Biochemie und Molekularbiologie I', 'Abteilung III Alte Geschichte', 'Soziologie III', 'Molekulare Physiologie', 'Entwicklungs- und Molekularbiologie der Tiere', 'Musikwissenschaftliches Institut der Robert-Schumann-Hochschule Düsseldorf', 'Wissenschaftliche Einrichtung Mathematisches Institut', 'Lehrstuhl für Betriebswirtschaftslehre, insbes. Betriebswirtschaftliche Steuerlehre', 'Lehrstuhl für Betriebswirtschaftslehre, insbes. Controlling und Accounting', 'Lehrstuhl Organische Chemie und Makromolekulare Chemie II', 'Medizinische Fakultät', 'Institut für Anorganische Chemie und Strukturchemie', 'Institut für Klassische Philologie', 'Poliklinik für Zahnärztliche Prothetik', 'Zentrum für Innere Medizin und Neurologie', 'Evolutionsgenetik', 'Klinische Pharmazie und Pharmakotherapie', 'Abteilung II Neuere Geschichte', 'Lehrstuhl Theoretische Physik I', 'Institut für Biochemie', 'Klinik für Hämatologie, Onkologie und klinische Immunologie', 'Institut für Molekulare Medizin I', 'Institut für Anglistik und Amerikanistik', 'Wissenschaftliche Einrichtung Physik', 'Biological Data Science', 'Abt. I: Germanistische Sprachwissenschaft', 'Institut für Arbeitsmedizin und Sozialmedizin', 'Abteilung I Mittelalterliche Geschichte', 'Betriebswirtschaftlehre', 'Institut für Bio- und Geowissenschaften, IBG-1, Forschungszentrum Jülich GmbH', 'Politikwissenschaft III', 'Anglistik IV: Modern English Literature', 'Abteilung für Soziologie', 'Externe Mitarbeiter, Lehrende und Gäste der wirtschaftswissenschaftliche Fakultät', 'Lehrstuhl Theoretische Physik IV', 'Institut für Physikalische Biologie', 'Abt. III: Deutsche Sprache und Literatur des Mittelalters', 'Lehrstuhl für Organische Chemie I', 'Molekulare Enzymtechnologie', 'Quantitative Genetik und Genomik der Pflanzen CEPLAS', 'Kommunikations- und Medienwissenschaft I', 'Zoologie/Organismische Interaktionen', 'Institut für Rechtsmedizin', 'Synthetische Mikrobiologie CEPLAS', 'Lehrstuhl Theoretische Physik II', 'Abteilung für Jüdische Studien', 'Institute und Forschungseinrichtungen', 'Biochemie der Pflanzen', 'iGRAD - Interdisciplinary Graduate and Research Academy Düsseldorf', 'Gräzistik', 'Lehrstuhl für Betriebswirtschaftslehre, insbes. Marketing', 'Zentrum für Operative Medizin I - Chirurgische Klinik und Poliklinik', 'Institut für Biochemie und Molekularbiologie II', 'Abteilung für Informationswissenschaft', 'Chemische Biologie der Proteinaggregation', 'Abt. II: Neuere Dt. Literatur - Lehrstuhl Prof. Dörr', 'Frauenklinik', 'Abteilung für Jiddische Kultur, Sprache und Literatur', 'Juristische Fakultät', 'Kommunikations- und Medienwissenschaft IV', 'Abt. I: Germ. Sprachwissenschaft - Professur Prof. Kasper', 'Botanik', 'Leibniz-Institut für Umweltmedizinische Forschung an der Heinrich-Heine-Universität Düsseldorf gGmbH', 'Zellbiologie', 'Abteilung VIII Geschichte der Frühen Neuzeit', 'Fakultäten', 'Lehrstuhl Theoretische Physik III', 'Hals-, Nasen- und Ohrenklinik', 'Zell- und Interaktionsbiologie CEPLAS', 'Institut für Theoretische Physik', 'Lehrstuhl für Betriebswirtschaftslehre, insbes. Arbeit, Personal und Organisation', 'Biomolekulare Festkörper-NMR-Spektroskopie', 'Pflanzengenetik CEPLAS', 'Trainingszentrum für ärztliche Fertigkeiten', 'Klinik für Gastroenterologie, Hepatologie und Infektiologie', 'Klinik und Poliklinik für Psychiatrie und Psychotherapie der Heinrich-Heine-Universität Düsseldorf - LVR-Klinikum Düsseldorf', 'Institut für Pharmakologie und Klinische Pharmakologie', 'Poliklinik für Zahnerh ...

# %% [markdown]
# ### Lade openAI-API
#
# Für das Matching der Organisationsnamen, die aus dem Scraping kommen mit denen der GERIT-Organisationen benötigen wir Embeddings. Dies Embeddings werden mit Hilfe der openAI-API erzeugt. Aus diesem Grund wird der openAI-API-Key im folgenden aus dem Enviorment geladen.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ### Embeddings generieren
#
# Im folgenden wird die OpenAI-API verwendet, um Embeddings der GERIT-Organisationen zu erzeugen und mit hilfe von Langchain eine In-Memory-Vektordatenbank für GERIT-Organisationen zu erstellen.
#
# In einem ersten Schritt wird das OpenAI-Embedding-Modell `text-embedding-3-large` initialisiert. Danach wird eine InMemoryVectorStore-Datenbank erstellt, die diese Vektoren speichert.
#
# Nun werden die GERIT-Organisationen aus dem Pandas-DataFrame (`df_gerit["Einrichtung"]`) in `Document`-Objekte umgewandelt. Diese Dokumente enthalten die Namen der Einrichtungen als `page_content`. Schließlich werden diese Dokumente mit ihren Embeddings in die Vektordatenbank eingefügt. Dadurch können später Ähnlichkeitsabfragen durchgeführt werden, um Organisationen mit ähnlichen Namen oder thematischen Schwerpunkten zu finden.

# %%
import openai
import pandas as pd
from typing import List
from langchain_openai import OpenAIEmbeddings
from langchain_core.vectorstores import InMemoryVectorStore
from langchain_core.documents import Document
from langchain_core.runnables import chain
from langchain.agents.agent_toolkits import create_retriever_tool

embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

vector_store = InMemoryVectorStore(embeddings)

docs = [Document(page_content=einrichtung) for einrichtung in df_gerit["Einrichtung"].tolist()]
vector_store.add_documents(docs)
# Out:
# ['f14f7328-f395-4244-a2c3-254d712ff8f5',
#  '13b906a4-d996-432c-8107-dfbf8aa036ef',
#  '043cd84a-ce15-45ef-9fb1-9f805dbf9778',
#  '8a1a7c70-675b-48e2-9d7f-71bcb8c9ade0',
#  'ee0b2aee-5ed5-46b0-8b6c-0543ddb31490',
#  '00a71a83-b9fe-46f0-91a7-2784bba5c6b1',
#  '4651d70e-059f-4689-9111-cd926a7b7300',
#  'ea094dca-3bcf-43b1-a6cb-ff16a90142fa',
#  '5722d33d-1566-425d-a32f-f764cb4598c1',
#  'f9ebbfea-e155-4e4c-9673-774af2445327',
#  'ed5e6c56-51df-4c77-b1a3-d68d3468b9ac',
#  '27ff7469-b3a2-42dd-a507-ddf892836173',
#  '7b5b248e-637e-47b8-9c35-a5e274b054fe',
#  '8f2dd337-d619-48b6-b98d-a1ee44a5c354',
#  'fda146ab-9725-4032-8f71-6612b5a54884',
#  '6e610a25-d95c-43b1-bb59-223a8d3fa372',
#  '3842b1d2-8b59-4b9f-bb1d-d44ae935c800',
#  'fb1e275d-244c-4c0c-bfce-4895a31e34ce',
#  '5783a005-d37b-4134-9b5c-acb113ee36da',
#  'd43b20e8-dd0f-4a5c-8c53-79f616de7880',
#  '6c2f382a-8a9b-4228-aca9-18ac45a0e48e',
#  '6f8095a9-34b2-4810-b195-d016465854ec',
#  '8e73a14a-f323-4892-b93a-6ba4f8b43c03',
#  'd806a891-72ac-45cb-80f8-afab82b754bc',
#  '346d5e79-2800-47b7-a484-46ec349b1b51',
#  '13fa57ca-5733-4b10-b4e7-ec7af1a68da3',
#  'd5d99b94-36b4-4cad-83b1-7b2449c5accb',
#  '88c8b35a-3a79-4703-ba85-2338aafeb769',
#  'c87e72b7-550f-40d7-b82e-d6780d832026',
#  '8ba74f7f-0186-4693-9170-addcd10d8dd2',
#  'd04b529d-8554-45fb-b445-76e19d101d29',
#  '83c1bdcf-d630-4680-8963-b246ccdaa297',
#  'ee13a86b-89e4-40c3-8361-4e4d196b3349',
#  '25830a05-ec1a-4a46-95bf-7e728f462a0d',
#  '0a47b935-7fed-4515-b509-25aab458fa47',
#  'b10877c2-11aa-4940-a580-065f4118edc4',
#  '2984ef75-2eb6-43ba-be72-6f0248b3c8b3',
#  'd64589f0-5db3-48c5-ad14-ee97864b0ebe',
#  '5984853d-266c-460a-990c-76edb182657d',
#  '336cc53b-536f-425a-be02-d92fbbff0372',
#  '005a81d4-8efe-4748-8be1-493e81992ed0',
#  '256a6386-6988-46eb-b8d5-e669c02401e3',
#  '2aa2ba4b-9f26-4982-a6d7-eaab0b700ae5',
#  '7e8b2b27-b870-43c4-af03-7084400046dc',
#  'f54abb11-123e-468c-8598-77faf39d0b13',
#  'da09f502-47bd-494f-a55c-b4cc05f2f661',
#  'ca51ebe9-48d4-4464-a444-955d0a8b9e60',
#  '00228042-e7b0-4436-abfb-c30c6311d529',
#  'f31fa700-624a-4ca0-9b38-7576abbd660e',
#  'a08be80d-f009-40dc-a9d6-b11b29949034',
#  '835359e3-8574-44ac-a7af-4ee251f1d0fe',
#  'ba78c625-0d01-448f-84a8-8ff44db5ccf3',
#  '8920f705-ce32-47bb-ae22-c7a5708e4f21',
#  'ffe26ce8-db84-40f9-a04d-5d624f7e89bf',
#  '625dcb3f-8721-4462-b3c0-755de076debe',
#  'eca3041a-7195-4d48-b5f8-20b0d3a2dfa4',
#  'f541a2ce-88b3-4d36-9053-1f205443d0e5',
#  '6ff33d86-702e-4786-8d2b-d8ef922565cd',
#  '0f067588-210d-4667-98e7-3458346263d9',
#  '13fda55d-6aa8-4598-a49d-bc341da4e8fa',
#  '4909d55d-88bd-456f-8f40-710849c3dc21',
#  'a9f0b2ab-849f-46da-b734-25a238df8dae',
#  '30482404-ce17-4c23-a085-a1eb136de90d',
#  'f0a0b6b5-1595-4d60-9dbb-acd120f7d6fb',
#  '04b0e927-0b01-41de-8e95-ddac01e910a4',
#  '06c92c33-4270-474c-86b3-088e3d9e069b',
#  'b288de98-7e66-46a3-aac3-44105aa03147',
#  'e06b8785-3917-4439-bdd0-b659bdfdade8',
#  '6562bb28-3e42-4d48-8dff-5eadc05bed6e',
#  '46556178-b85a-4918-b017-ab102f54a1aa',
#  'e70f8f80-03d1-4638-91a3-2c0b65a3b681',
#  '7aa7bf4f-afb7-458e-8e9b-290da55c6b68',
#  '68b23d77-7773-478e-a641-dadf7665db37',
#  '19d12599-b455-4db7-94e8-1441f2ef5f97',
#  'a1c7230a-bacd-4d64-b4bb-bcdd2c1a1f6e',
#  '3ac33a67-b5ea-4f74-9ed2-a66197bf6822',
#  'b6397b49-b5ab-4a6c-bac3-9761f0faeb89',
#  '91c40ff3-c12a-4e89-b1d9-f16cf0312b5a',
#  'e3133479-6769-481f-90e8-ba7b31daa957',
#  'de36d80e-72e4-4791-9ed3-5ca648649d09',
#  'fd95b2b4-4d92-44da-9971-1644f5aeab16',
#  '9273899c-8614-4246-ae15-109c238fa9d0',
#  '67f174eb-06b2-40ce-98be-ecdd88073af3',
#  'a8216573-07f6-441e-b915-2f628ce59fec',
#  '9edc9b8e-7082-482f-81bc-558a8dc25a0e',
#  '0dc978e8-03f5-4331-ad65-8f42b9ada735',
#  '4fd7bb00-56fb-4282-adb9-a623a235c7ad',
#  '045f29d9-f093-49f3-98c5-b69c07adab54',
#  '7f602dcb-1bc7-453c-adc9-5b09d3e1eab3',
#  'ab2284b4-0c75-4a64-a237-ba4d530d9fa8',
#  'f86ad947-9b8c-48c4-823a-232d23f18098',
#  '93548629-4ae1-42d9-91dd-e5df72add706',
#  'fe7daa46-5353-4afd-813a-10770f40f379',
#  '351db7a8-461f-46f1-8e71-e3786e42f2b7',
#  'f8a3550a-ae95-4892-b7c5-a9fdbeb0d1b0',
#  '5b851af5-fbd7-4334-bcbe-ec4ca4bb0fb4',
#  'a5882111-3e85-48b5-9764-4bc2322f4526',
#  '5c675392-3f19-43bf-86d8-829965aa0360',
#  '9fcd3676-dcd5-4eba-b503-03808f2dc0ee',
#  'f3408e4a-5db6-4f53-ab0f-e5050f70f5ba',
#  '2131448e-efc2-4146-8ef1-1f090bdab5ca',
#  '070c78d4-fe5c-403a-b89b-8af5c7f7e296',
#  '88cd4b20-223a-439a-adbf-d34f1a85bf58',
#  '1b647742-caa8-46e7-9bcc-14d0671985e9',
#  'a7e35fe8-b9fd-42d0-bfd3-9aaa23ab562a',
#  '3ab4161d-21ee-4dde-97e9-fb2b64adb5d6',
#  '7f8c1400-c9f9-4600-8715-1b9b68cbf43e',
#  '4c2569b7-477b-4a9f-b544-58a90d0e2c09',
#  '1dde5c7d-fd6c-4b81-8e8d-a409a895acc6',
#  '17aed941-b38e-4dfa-8d18-fedb8500fc9e',
#  'def96b2c-63b9-4ea6-9f7c-1168c757d94b',
#  '7b71fc4c-1c19-4554-94f0-33fcb75b5f82',
#  'a2fd4030-3a18-49a6-8585-9ddf28dea740',
#  '534ba6a5-514e-414b-af08-ba01cbcdcf0e',
#  '001630ac-f53e-43b5-8df1-3b7e6e56d20a',
#  'b494ae66-fe92-442d-a045-e85141a1b1c5',
#  '555c31f6-1885-428f-8a1c-87e2bac21abb',
#  'd4f1a674-dad7-43d9-8612-28eff927ea15',
#  'edb05ca7-37e2-48e8-90ac-8b9db1a0f4c0',
#  '0a01c2bb-3eb0-488c-a230-ed6a1baa9cdb',
#  '05b20b30-be04-46f5-aada-491bc0afc961',
#  'a5df2fa5-413f-41fc-94ef-d5fb1f616bf4',
#  'c4f40d0d-13a8-4fff-a9f2-2a1f8a9c9dcf',
#  '305ec22b-59be-4f08-b20b-9655f54cb3f4',
#  '891bff96-8d56-4903-aa4b-e3e9fb1e031d',
#  'e8ef78ef-efac-4ff3-b6cb-0a8d54f4baa9',
#  '0f9d5612-ee42-4028-9bb7-68edd2d373d9',
#  '6b0c3b0b-54e6-495d-a240-a27b5deb77f0',
#  '71255258-a588-4ba1-bac9-fe27e8abae1c',
#  '69a66e7a-0dd7-4bd1-901b-029c2ea4169e',
#  '75c9251e-79c8-46ad-979a-4a064f5427dc',
#  '4334db35-0c8f-44f7-959a-11407d747f1c',
#  '61f9c1b7-fefa-47d1-88d5-85f2b9f9f16e',
#  '4927d532-740b-433e-877d-1582169588fa',
#  '9fd8c279-5de9-4c22-a140-bf9a3bbbf4e2',
#  '078909f3-fd60-4c35-b860-89dd4b5be067',
#  'a69982b0-5316-4f3b-b2a2-825a63453c85',
#  '3e918db9-096a-4335-bd35-0672a6d2b5bf',
#  '2580d152-d4e0-4799-927f-1b56823755c1',
#  '0469d824-110c-44fa-8337-7bd4ea4f8e9a',
#  '27474f01-8bc8-4d8c-9e6f-a8347557a079',
#  'c75f2089-da6c-4e6b-b50b-65cdbf0dc5c5',
#  '779908fb-c248-458b-b650-28ca0274e815',
#  '1229b8bb-2070-4b67-ae36-3a8069cfc358',
#  'bc240770-8e19-48f4-b90f-d415a38654f8',
#  '916d2c2c-354b-41d8-a61a-fc3056a49037',
#  '2e775587-b055-4b37-80d9-8daa5f6ebf0b',
#  '2b22dced-db8a-49ef-8267-0ce4618db014',
#  '52393091-cacd-4126-b4d3-a31537450441',
#  '8f2f5fc5-50b4-4ee1-b7ae-374cbc879e8e',
#  'f52be500-92b9-435c-83eb-2b6464d6bf72',
#  'a077c546-7f57-401f-b567-f06aa5026f9f',
#  '85e8d12b-40ff-468b-9402-c8f5d2bf1acf',
#  '1ffb3eb4-bce2-414d-aeb0-e9f0849b08b0',
#  '27e5aa50-8daf-4d11-8fdc-2267762c2623',
#  'fa24596b-0b37-4927-b591-87f1fa8e6cc9',
#  '85c89314-769e-4aa6-a6b7-bee8f313ca68',
#  '0b064143-451a-4686-9c19-2890555ec947',
#  'b01d2c4a-fe5e-402f-85e5-899099006fcd',
#  '515dfa27-9ff1-4af0-9f3e-bf898643dc7e',
#  '09cfc918-cca7-4ff4-ba1f-445e89532869',
#  '84ba9d75-2d13-4f72-a8ca-72e24b289af8',
#  'd551b21a-24ee-41df-89bc-b6d860a8792c',
#  'a83691ef-8b5a-498b-9f4c-e51b9a59a664',
#  '9c7ce58a-6e89-4d56-8337-875c0cbda76f',
#  '6dfaaa3f-c666-4bfe-815a-a44866a2dce3',
#  '1b08978f-729e-41af-9b5d-5c33410915d9',
#  'bb36f584-77dd-4054-8fa2-5d304c06a3a7',
#  'f4272452-6c46-43d0-bf47-f3481f24ca79',
#  'a88dbe8a-970e-46f0-9f5e-a05bb92d0996',
#  'c1b26420-f4cd-4d65-aa71-ea2e2738a4bf',
#  'dd5dbe1d-cab9-47b8-ba33-08d6863420db',
#  '11c25743-e197-483b-a441-9764d24df6f0',
#  'd280ac97-aade-4b37-9e37-4f0353a9ae5e',
#  '3ccfcc18-5bf8-4937-8c08-e58405b7add3',
#  '19ca11cf-d773-48c8-8225-a17e6571bac6',
#  '5da4d301-8a0a-44ec-9f29-7e05ef720a0b',
#  '6df67a9b-e55c-4710-81d4-6374018609dd',
#  'f0b62e98-7221-4022-aee3-b8157348b24b',
#  '06d8c55d-58d1-42dd-9f7e-4f1fe8863f65',
#  '20fcfc21-4f2b-44f3-95ce-d17f98806677',
#  '84dd358f-970b-4114-8e8b-a788a2e39d34',
#  '8b735db9-641c-4fcb-bc51-1a20384f26df',
#  '42e98b33-a732-45c4-b074-8a2181ba39a9',
#  'a7ef42f7-c0f7-4405-b8ed-9611012bcf90',
#  '6bc1068d-28d9-48e8-bceb-160494adfbad',
#  '3cc1b231-5789-4e39-9bc8-21ff4495fe15',
#  '38b44fe7-6cb4-4904-bf09-91957efc8af0',
#  '0d0a8fed-f800-4300-ad0e-07306689363e',
#  'd65aaf12-886e-470c-84ce-35287bbc1a0e',
#  '4953a440-a6ae-4126-9c9a-3696db3efb07',
#  '584bc915-8707-4bd3-ac09-33c4bf2b5a4f',
#  'e4673281-22ca-4b3d-b658-f1bbdf084dfd',
#  '88ff0b18-a28e-4b01-8a54-dfc46ef44c70',
#  'cc26f36d-339d-49e2-b84a-85be18a59314',
#  '70a25626-c753-4862-9519-1db1838ca81f',
#  '3c709de2-1fcb-44a4-8259-d4c26e5d95aa',
#  '5f37bfec-7e40-49de-9c32-1943768fe1e6',
#  'f8f62fd0-5f1f-4d50-b3f5-4964d01de055',
#  '759330b7-1aa5-4305-8a47-524dff35afb1',
#  'a92402c3-67e7-48cc-8a5d-c06b8aeb17af',
#  '2f36ff7c-5676-4225-9c78-bc7ac116e4a6',
#  'f4535427-ea70-4358-9aee-d060fd1eae5c',
#  'e6bc9560-0b1f-45b9-bd47-a10bbb4672fa',
#  'ead73279-f5c0-4a20-9270-750fc6f79536',
#  '83c71602-6eb0-4252-930d-9320228ff6ea',
#  '9cb63a08-6dee-47bb-93a2-01a720e0562f',
#  'aaa455e9-f118-4450-98b2-0aad048a36ab',
#  'fa03e0fe-a854-4a5d-8897-3b2c44fab92c',
#  '948c5ee6-2854-48c4-beeb-97b5590d6168',
#  'c0f76323-9c3c-41e1-a466-d61879962811',
#  '137ddeb7-cedd-4c97-ba29-972702822d0c',
#  'b8272dff-6afc-4fb0-8352-db29a5e70075',
#  '472a9d29-e9d5-4126-ada5-496a459d858d',
#  'c9c711e2-7ffb-4952-baff-61a703fadc8a',
#  '42c76ce9-c532-48c7-b8b3-ea70e0e28ccb',
#  '26b35792-d35f-46e9-a5e2-742e32d30451',
#  '188a41b9-4242-4555-b6ac-cd165f0c0ce4',
#  '46568e18-2231-4ae3-8f2c-ef664db381fd',
#  'ac1506c5-8bcd-4fa4-9443-dbaabe837cf1',
#  'eb94dbaa-7285-4eb2-922a-e5aa975053ce',
#  '38098df3-065c-4f6a-8ca9-ccc096178afd',
#  'bf0f6e49-1364-4033-8d9a-a55b960790c5',
#  '8400aa85-38d8-4003-80ef-935bcf0ba019',
#  'c42a5ae0-b4bf-4743-9f57-ef7c4a2ecd5d',
#  'ade98a8d-7868-474b-929a-9cdfa5bd38ab',
#  '80608d25-cc95-4af8-801b-4b00e09f7130',
#  '531a76cd-b8dc-49f8-848c-1696944d7503',
#  'e4ef34b7-1661-4093-a255-fb5e4446ede1',
#  '3a47b628-b397-4ee7-a96f-d7c9f5caae71',
#  '1d8321ae-710b-4331-84ec-b49465acdf09',
#  '01e113e7-1825-431f-9e0d-5fa5e0f9201f',
#  '05025519-2540-4d27-86d3-dcd864fd57a1',
#  '327ee81c-1652-41c3-8ec0-a06d7b34a204',
#  '2e849336-6691-4225-adce-5d261f699c08',
#  'c414fa03-8fe7-4848-b85a-be751e21f72e',
#  'f809209c-5646-47f5-9204-102ac05377dd',
#  '9337647e-d965-48bc-a04d-1407e3ca6a54',
#  '8309e983-76b9-4fad-b952-1cd53c8ecf4f',
#  'db30bfc6-5591-4ae9-ad45-ed63236e51c0',
#  '9bb68347-c07f-449a-9d69-15e04956d619',
#  '5918231b-3ce9-4eca-9004-6cb45a124719',
#  'a6ec8d61-57b4-45eb-8e1e-2ccd72295dc0',
#  'b4798da1-4221-4a39-b951-3bd5824092d7',
#  'fbd8f401-e5b1-4753-8e23-455673d76255',
#  '801e2e87-36d0-46d6-bfdf-a293a7238097',
#  '1d9135fd-a289-4582-a0c8-537d49a611f2',
#  '55f7fa21-5c10-4d64-88ab-8eded6333791',
#  '30c41805-4f45-4bcb-b672-12af898ca3c2',
#  '3fbca959-3d3d-4fc9-889c-128b51e9a6bb',
#  'b03d8b7d-3050-4577-9d4f-3cc3e621f58d',
#  '353dda89-3e10-446c-8bbf-d54fabcc5b17',
#  '72e0265c-5bd6-44d5-9df7-69832669915d',
#  'cc487cc6-81ff-42e8-9542-ecaffdfcc2d1',
#  '632498de-59e6-4bbb-bb80-67b92dc1da1b',
#  '7e99a05c-d61a-4e2f-82b5-8c120803edeb',
#  '8b01614a-7363-4d8a-8fe4-54197774b6d1',
#  '672ce2f1-6972-4f76-892f-be3a86e70cd7',
#  'e9a7abcd-9b3b-4535-a982-7ee748a7b70a',
#  'c1ea91dd-8e55-4a3e-bcd0-4b1a82061048',
#  '679a9737-71fd-4837-92da-66a8c40e6b36',
#  'cc9fade5-c59d-4ade-ad57-f975f8bc2a06',
#  '4249c9e1-8336-4f4b-bc09-ab35d650e152',
#  'e4bb68bd-781e-4944-9e6b-d379e910f6f8',
#  'cb151b41-207a-46a0-b34c-44e0d6361db5',
#  '3835613e-5402-4b74-a608-1637edd9223f',
#  'c32912c8-eb67-4786-9cb4-3d843898cfe4',
#  'fecf4d6f-026b-44ec-9a1a-c3ba4ad2b9c3',
#  'a89f836e-1008-4fec-bfc4-acf8b91839a6',
#  'f34abb1b-03c3-4206-b17e-ffaaddf37551',
#  'eb7cbfcf-349d-4bd2-a41d-1bc5bc0e9d8b',
#  '7f64e564-e198-4b5b-8020-80b4bfd31a91',
#  '2e000ac3-bf01-49a2-8e8e-20b310bb644a',
#  '8c1cf29c-43f4-431e-be18-4fb2489f3031',
#  '29a16bcc-89f7-405d-b296-ceb3f7db3473',
#  'a8b03833-6bc9-4937-bf85-33ec26d23681',
#  '3a82b68c-03c8-47e0-92b8-522d7d0dd25d',
#  '3678c878-7dc5-411a-8fd7-93a424f0885a',
#  '5db75c2c-1a99-48ca-81e5-4981d7a1ca0b',
#  '0f481a58-2eb2-4cc7-bc09-540eb43e4799',
#  'ee8a2d88-268b-4e59-a251-6db7087f1476',
#  '4e724372-c677-4df1-9822-c29c96c9c4fa',
#  'f6eb1e49-9504-445d-875e-c3cce3496ccb',
#  'c92b14c1-c956-4887-8103-edea30e6549a',
#  '765cb1b6-a28a-4968-a5f5-d81cabf82db9',
#  '8b26763f-63fd-45ac-bac3-54bd21338f04',
#  '7e9f0cd4-dbf5-4ded-9cd8-ed1c9eb58f78',
#  '1f82a53c-5880-47e9-890b-5e5a7bbdba75',
#  '69544ba2-220d-4e29-942d-ce08f19df1be',
#  '6b7d1f39-85f2-48f5-8c83-f3f81b609933',
#  'f6852e8b-7a89-4842-844f-231ddbb7c329',
#  '17ac575c-d569-4150-ab89-b311e7179c71',
#  '46e60b7b-5d80-4d1f-8d2a-8f7548b4d55b',
#  '8c4189df-c9a8-4a66-a08b-1988bc755d49',
#  'de0c781f-33f8-480e-842c-7cce90b55716',
#  '937faea4-1d49-4e11-b155-8474d8238b89',
#  'e24be487-fc05-4b22-bc75-882d5882c789']

# %% [markdown]
# ### Erzeuge Retriever
#
# Im weiteren definieren wir eine Retriever-Funktion, die anhand einer Suchanfrage ähnliche Dokumente aus dem oben definierten Vektor-Store findet und ihre Ähnlichkeitsscores zurückgibt. Dazu wird die Funktion `retriever` mit `@chain` als Teil einer Verarbeitungskette registriert. Die Suche erfolgt mit `vector_store.similarity_search_with_score(query, k=5)`, wodurch die fünf ähnlichsten Dokumente ermittelt werden. Falls Ergebnisse vorhanden sind, werden sie in Dokumente und Scores aufgeteilt. Jedes gefundene Dokument erhält seinen Ähnlichkeitsscore als Metadaten.
#
# Zusätzlich wird eine Beschreibung für den Retriever erstellt, die erklärt, dass die Funktion nach gültigen Eigennamen basierend auf einer ungefähren Eingabe sucht und die Ähnlichkeitsscores zurückliefert. Falls keine passende Entsprechung gefunden wird, wird stattdessen "NA" zurückgegeben. Schließlich wird mit `create_retriever_tool` ein Tool erstellt, das die definierte Retriever-Funktion mit der angegebenen Beschreibung verbindet und als `retriever_tool` gespeichert wird.

# %%
# Definiere den Retriever als Chain mit Scores
@chain
def retriever(query: str) -> List[Document]:
    results = vector_store.similarity_search_with_score(query, k=5)
    docs, scores = zip(*results) if results else ([], [])

    for doc, score in zip(docs, scores):
        doc.metadata["score"] = score  # Füge den Score als Metadaten hinzu

    return list(docs)

# Beschreibung für den Retriever
description = (
    "Sucht nach gültigen Eigennamen basierend auf einer ungefähren Eingabe und gibt die Ähnlichkeitsscores zurück. "
    "Falls keine passende Entsprechung gefunden wird, wird 'NA' zurückgegeben."
)

# Retriever-Tool erstellen
retriever_tool = create_retriever_tool(
    retriever,
    name="search_proper_nouns_with_score",
    description=description,
)

# %% [markdown]
# #### Teste Retriever
#
# Wir testen im folgenden den Retriever auf Funktionalität.

# %%
query = "Physikfdalische Chemie"
results = retriever.invoke(query)

# Ergebnisse anzeigen
for doc in results:
    print(f"Text: {doc.page_content}, Score: {doc.metadata['score']}")
# Out:
# Text: Institut für Physikalische Chemie, Score: 0.7465456896876095
# Text: Lehrstuhl für Festkörperphysik, Score: 0.6288085595609698
# Text: Institut für Theoretische Chemie, Score: 0.6284249496503709
# Text: Lehrstuhl für Molekulare Physikalische Chemie (MPC), Score: 0.6104274537375814
# Text: Lehrstuhl für Physik der weichen Materie, Score: 0.5993830425468181

# %% [markdown]
# #### Erzeuge Matching-Funktion
#
# Die Funktion `match_unique_organisations` führt eine unscharfe Suche für Organisationsnamen durch und erstellt eine detaillierte Matching-Tabelle. Sie verarbeitet eine `pandas.df` mit Organisationen, wobei Organisationen, die durch `";"` getrennt sind, einzeln betrachtet werden.
#
# Zunächst wird ein leeres Rekodierungs-Dictionary (`recode_dict`) und eine Liste für die Matching-Ergebnisse (`matching_data`) erstellt. Für jede Organisation im Eingangs-Data Frame wird geprüft, ob sie durch `";"` getrennte Einträge enthält, die dann separat verarbeitet werden.
#
# Für jede Organisation wird der `retriever` verwendet, um eine unscharfe Suche durchzuführen. Falls das beste gefundene Ergebnis einen Ähnlichkeitsscore von mindestens `0.65` hat, wird es als Match übernommen, andernfalls bleibt die ursprüngliche Organisation bestehen. Das Ergebnis wird mit einer entsprechenden Matching-Art (`Fuzzy` oder `Keine Übereinstimmung`) und dem Score gespeichert.
#
# Das `recode_dict` enthält die ursprünglichen Organisationen als Schlüssel und die zugeordneten Werte als Zeichenketten mit `"; "` getrennten gematchten Namen. Der `matching_df` speichert detaillierte Informationen über das Matching, einschließlich des ursprünglichen Wertes, des gematchten GERIT-Wertes, des Matching-Typs und des Scores.
#
# Am Ende gibt die Funktion das Rekodierungs-Dictionary und den DataFrame mit den Matching-Details zurück.

# %%
import pandas as pd

def match_unique_organisations(org_df, retriever):
    """
    Funktion, die nur einzigartige Werte der Organisationen verarbeitet und eine detaillierte Matching-Tabelle erstellt.
    
    :param org_df: Pandas Series mit den ursprünglichen Organisationen
    :param retriever: Retriever zur unscharfen Suche
    :return:
        - recode_dict: Dictionary mit den rekodierten Werten (Originalwert → gematchter Wert)
        - matching_df: DataFrame mit Matching-Details (ursprünglicher Wert, gematchter Wert, Matching-Art, Score)
    """
    print(f"Anzahl einzigartiger Organisationen in den Eingabedaten: {len(org_df)}")

    recode_dict = {}
    matching_data = []  # Liste für die Matching-Ergebnisse

    for org in org_df:
        orgs = [o.strip() for o in org.split(';')]  # Aufteilen bei ";", Leerzeichen entfernen
        matched_orgs = []
        match_details = []  # Speichert Match-Typ und Score für jede Organisation in einer Zeile

        for o in orgs:
            match_type = "Keine Übereinstimmung"
            score = None
            matched_value = None

            # Unscharfe Suche über den Retriever
            results = retriever.invoke(o)

            if results and results[0].metadata.get("score", 0) >= 0.65:
                matched_value = results[0].page_content
                score = results[0].metadata["score"]
                match_type = "Fuzzy"
                print(f"Fuzzy Match gefunden: '{o}' → '{matched_value}' (Score: {score:.2f})")
            else:
                print(f"Kein passender Match für '{o}' gefunden.")

            # Speichern des Matches
            matched_orgs.append(matched_value if matched_value else o)  # Falls kein Match, Original behalten
            match_details.append({
                "Ursprünglicher Wert": o,
                "Gematchter GERIT-Wert": matched_value,
                "Matching-Art": match_type,
                "Score": score
            })

        # Rekodierungs-Dictionary speichern
        recode_dict[org] = "; ".join([m for m in matched_orgs if m]) if matched_orgs else None

        # Matching-Details zur Liste hinzufügen
        matching_data.extend(match_details)

    # DataFrame aus den Matching-Daten erstellen
    matching_df = pd.DataFrame(matching_data)

    return recode_dict, matching_df

# %%
recode_dict, matching_df = match_unique_organisations(unique_values, retriever)
# Out:
# Anzahl einzigartiger Organisationen in den Eingabedaten: 247
# Fuzzy Match gefunden: 'Abt. IV: Theorie und Praxis (Mündlichkeit)' → 'Abteilung IV: Lehrstuhl Theorie und Praxis mündlicher und schriftlicher Kommunikation' (Score: 0.67)
# Fuzzy Match gefunden: 'Institut für Biochemie der Pflanzen' → 'Institut für Biochemie der Pflanzen' (Score: 1.00)
# Kein passender Match für 'Dekanatsbüro Phil. Fakultät' gefunden.
# Fuzzy Match gefunden: 'Institut für Geschichte, Theorie und Ethik der Medizin' → 'Institut für Geschichte, Theorie und Ethik der Medizin' (Score: 1.00)
# Fuzzy Match gefunden: 'Zentrum für Pharmakologie und Toxikologie' → 'Institut für Pharmakologie' (Score: 0.78)
# Fuzzy Match gefunden: 'Neurobiologie' → 'Angewandte Neurobiologie' (Score: 0.78)
# Fuzzy Match gefunden: 'Quantitative und Theoretische Biologie CEPLAS' → 'Institut für Quantitative und Theoretische Biologie' (Score: 0.74)
# Fuzzy Match gefunden: 'Institut für Neuropathologie' → 'Institut für Neuropathologie' (Score: 1.00)
# Fuzzy Match gefunden: 'Klinik für Anästhesiologie' → 'Klinik für Anästhesiologie' (Score: 1.00)
# Fuzzy Match gefunden: 'Institut für Klinische Diabetologie' → 'Klinik für Endokrinologie und Diabetologie' (Score: 0.77)
# Kein passender Match für 'Zentrale Einrichtung für Tierforschung und wiss. Tierschutzaufgaben' gefunden.
# Fuzzy Match gefunden: 'Molekulare Evolution' → 'Institut für Molekulare Evolution' (Score: 0.73)
# Fuzzy Match gefunden: 'Institut für Biochemie und Molekularbiologie I' → 'Institut für Biochemie und Molekularbiologie I' (Score: 1.00)
# Fuzzy Match gefunden: 'Abteilung III Alte Geschichte' → 'Lehrstuhl für Alte Geschichte' (Score: 0.76)
# Fuzzy Match gefunden: 'Soziologie III' → 'Lehrstuhl Soziologie III' (Score: 0.83)
# Fuzzy Match gefunden: 'Molekulare Physiologie' → 'Institut für molekulare Physiologie' (Score: 0.78)
# Fuzzy Match gefunden: 'Entwicklungs- und Molekularbiologie der Tiere' → 'Institut für Entwicklungs- und Molekularbiologie der Tiere' (Score: 0.82)
# Kein passender Match für 'Musikwissenschaftliches Institut der Robert-Schumann-Hochschule Düsseldorf' gefunden.
# Fuzzy Match gefunden: 'Wissenschaftliche Einrichtung Mathematisches Institut' → 'Mathematisches Institut' (Score: 0.87)
# Fuzzy Match gefunden: 'Lehrstuhl für Betriebswirtschaftslehre, insbes. Betriebswirtschaftliche Steuerlehre' → 'Lehrstuhl für BWL, insbesondere Betriebswirtschaftliche Steuerlehre' (Score: 0.96)
# Fuzzy Match gefunden: 'Lehrstuhl für Betriebswirtschaftslehre, insbes. Controlling und Accounting' → 'Lehrstuhl für BWL, insb. Accounting' (Score: 0.89)
# Fuzzy Match gefunden: 'Lehrstuhl Organische Chemie und Makromolekulare Chemie II' → 'Lehrstuhl für Makromolekulare Chemie' (Score: 0.89)
# Fuzzy Match gefunden: 'Medizinische Fakultät' → 'Juristische Fakultät' (Score: 0.68)
# Fuzzy Match gefunden: 'Institut für Anorganische Chemie und Strukturchemie' → 'Institut für Physikalische Chemie' (Score: 0.78)
# Fuzzy Match gefunden: 'Institut für Klassische Philologie' → 'Institut für Klassische Philologie' (Score: 1.00)
# Fuzzy Match gefunden: 'Poliklinik für Zahnärztliche Prothetik' → 'Poliklinik für Zahnärztliche Prothetik' (Score: 1.00)
# Fuzzy Match gefunden: 'Zentrum für Innere Medizin und Neurologie' → 'Zentrum für Anatomie und Hirnforschung' (Score: 0.70)
# Kein passender Match für 'Evolutionsgenetik' gefunden.
# Fuzzy Match gefunden: 'Klinische Pharmazie und Pharmakotherapie' → 'Institut für Klinische Pharmazie und Pharmakotherapie' (Score: 0.80)
# Fuzzy Match gefunden: 'Abteilung II Neuere Geschichte' → 'Lehrstuhl für Neuere Geschichte' (Score: 0.75)
# Fuzzy Match gefunden: 'Lehrstuhl Theoretische Physik I' → 'Lehrstuhl IV: Theoretische Festkörperphysik' (Score: 0.80)
# Fuzzy Match gefunden: 'Institut für Biochemie' → 'Institut für Biochemie und Molekularbiologie I' (Score: 0.79)
# Fuzzy Match gefunden: 'Klinik für Hämatologie, Onkologie und klinische Immunologie' → 'Klinik für Hämatologie, Onkologie und Klinische Immunologie' (Score: 1.00)
# Fuzzy Match gefunden: 'Institut für Molekulare Medizin I' → 'Institut für Molekulare Medizin I' (Score: 1.00)
# Fuzzy Match gefunden: 'Institut für Anglistik und Amerikanistik' → 'Institut für Anglistik und Amerikanistik' (Score: 1.00)
# Fuzzy Match gefunden: 'Wissenschaftliche Einrichtung Physik' → 'Institut für Experimentalphysik' (Score: 0.73)
# Fuzzy Match gefunden: 'Biological Data Science' → 'Institute for Biological Data Science' (Score: 0.78)
# Fuzzy Match gefunden: 'Abt. I: Germanistische Sprachwissenschaft' → 'Abteilung I: Lehrstuhl für Germanistische Sprachwissenschaft' (Score: 0.75)
# Fuzzy Match gefunden: 'Institut für Arbeitsmedizin und Sozialmedizin' → 'Institut für Arbeits-, Sozial- und Umweltmedizin' (Score: 0.88)
# Fuzzy Match gefunden: 'Abteilung I Mittelalterliche Geschichte' → 'Lehrstuhl für Mittelalterliche Geschichte' (Score: 0.78)
# Kein passender Match für 'Betriebswirtschaftlehre' gefunden.
# Fuzzy Match gefunden: 'Institut für Bio- und Geowissenschaften, IBG-1, Forschungszentrum Jülich GmbH' → 'Institut für Bioorganische Chemie (IBOC)' (Score: 0.67)
# Fuzzy Match gefunden: 'Politikwissenschaft III' → 'Lehrstuhl Politikwissenschaft III' (Score: 0.85)
# Fuzzy Match gefunden: 'Anglistik IV: Modern English Literature' → 'Anglistik IV: Modern English Literature' (Score: 1.00)
# Fuzzy Match gefunden: 'Abteilung für Soziologie' → 'Abteilung Soziologie' (Score: 0.97)
# Kein passender Match für 'Externe Mitarbeiter, Lehrende und Gäste der wirtschaftswissenschaftliche Fakultät' gefunden.
# Fuzzy Match gefunden: 'Lehrstuhl Theoretische Physik IV' → 'Lehrstuhl IV: Theoretische Festkörperphysik' (Score: 0.87)
# Fuzzy Match gefunden: 'Institut für Physikalische Biologie' → 'Institut für Physikalische Biologie' (Score: 1.00)
# Fuzzy Match gefunden: 'Abt. III: Deutsche Sprache und Literatur des Mittelalters' → 'Abteilung III: Lehrstuhl Germanistische Mediävistik' (Score: 0.71)
# Fuzzy Match gefunden: 'Lehrstuhl für Organische Chemie I' → 'Lehrstuhl für Organische Chemie' (Score: 0.93)
# Fuzzy Match gefunden: 'Molekulare Enzymtechnologie' → 'Institut für Molekulare Enzymtechnologie (IMET)' (Score: 0.71)
# Fuzzy Match gefunden: 'Quantitative Genetik und Genomik der Pflanzen CEPLAS' → 'Institut für Quantitative Genetik und Genomik der Pflanzen' (Score: 0.77)
# Fuzzy Match gefunden: 'Kommunikations- und Medienwissenschaft I' → 'Abteilung Kommunikations- und Medienwissenschaft' (Score: 0.81)
# Fuzzy Match gefunden: 'Zoologie/Organismische Interaktionen' → 'Institut für Zoologie und Organismische Interaktionen' (Score: 0.72)
# Fuzzy Match gefunden: 'Institut für Rechtsmedizin' → 'Institut für Rechtsmedizin' (Score: 1.00)
# Fuzzy Match gefunden: 'Synthetische Mikrobiologie CEPLAS' → 'Institut für Synthetische Mikrobiologie' (Score: 0.75)
# Fuzzy Match gefunden: 'Lehrstuhl Theoretische Physik II' → 'Lehrstuhl IV: Theoretische Festkörperphysik' (Score: 0.82)
# Fuzzy Match gefunden: 'Abteilung für Jüdische Studien' → 'Institut für Jüdische Studien' (Score: 0.86)
# Kein passender Match für 'Institute und Forschungseinrichtungen' gefunden.
# Fuzzy Match gefunden: 'Biochemie der Pflanzen' → 'Institut für Biochemie der Pflanzen' (Score: 0.76)
# Kein passender Match für 'iGRAD - Interdisciplinary Graduate and Research Academy Düsseldorf' gefunden.
# Kein passender Match für 'Gräzistik' gefunden.
# Fuzzy Match gefunden: 'Lehrstuhl für Betriebswirtschaftslehre, insbes. Marketing' → 'Lehrstuhl für BWL, insbesondere Marketing' (Score: 0.95)
# Fuzzy Match gefunden: 'Zentrum für Operative Medizin I - Chirurgische Klinik und Poliklinik' → 'Klinik für Allgemein-, Viszeral- und Kinderchirurgie' (Score: 0.67)
# Fuzzy Match gefunden: 'Institut für Biochemie und Molekularbiologie II' → 'Institut für Biochemie und Molekularbiologie II' (Score: 1.00)
# Fuzzy Match gefunden: 'Abteilung für Informationswissenschaft' → 'Abteilung für Informationswissenschaft' (Score: 1.00)
# Kein passender Match für 'Chemische Biologie der Proteinaggregation' gefunden.
# Kein passender Match für 'Abt. II: Neuere Dt. Literatur - Lehrstuhl Prof. Dörr' gefunden.
# Fuzzy Match gefunden: 'Frauenklinik' → 'Klinik für Frauenheilkunde und Geburtshilfe' (Score: 0.81)
# Fuzzy Match gefunden: 'Abteilung für Jiddische Kultur, Sprache und Literatur' → 'Abteilung für Jiddische Kultur, Sprache und Literatur' (Score: 1.00)
# Fuzzy Match gefunden: 'Juristische Fakultät' → 'Juristische Fakultät' (Score: 1.00)
# Fuzzy Match gefunden: 'Kommunikations- und Medienwissenschaft IV' → 'Abteilung Kommunikations- und Medienwissenschaft' (Score: 0.78)
# Fuzzy Match gefunden: 'Abt. I: Germ. Sprachwissenschaft - Professur Prof. Kasper' → 'Abteilung I: Lehrstuhl für Germanistische Sprachwissenschaft' (Score: 0.70)
# Fuzzy Match gefunden: 'Botanik' → 'Botanischer Garten' (Score: 0.67)
# Kein passender Match für 'Leibniz-Institut für Umweltmedizinische Forschung an der Heinrich-Heine-Universität Düsseldorf gGmbH' gefunden.
# Fuzzy Match gefunden: 'Zellbiologie' → 'Institut für Zellbiologie' (Score: 0.74)
# Fuzzy Match gefunden: 'Abteilung VIII Geschichte der Frühen Neuzeit' → 'Lehrstuhl Geschichte der Frühen Neuzeit' (Score: 0.76)
# Fuzzy Match gefunden: 'Fakultäten' → 'Juristische Fakultät' (Score: 0.69)
# Fuzzy Match gefunden: 'Lehrstuhl Theoretische Physik III' → 'Lehrstuhl IV: Theoretische Festkörperphysik' (Score: 0.80)
# Fuzzy Match gefunden: 'Hals-, Nasen- und Ohrenklinik' → 'Klinik für Hals-Nasen-Ohrenheilkunde' (Score: 0.86)
# Fuzzy Match gefunden: 'Zell- und Interaktionsbiologie CEPLAS' → 'Institut für Zell- und Interaktionsbiologie' (Score: 0.73)
# Fuzzy Match gefunden: 'Institut für Theoretische Physik' → 'Institut für Theoretische Physik' (Score: 1.00)
# Fuzzy Match gefunden: 'Lehrstuhl für Betriebswirtschaftslehre, insbes. Arbeit, Personal und Organisation' → 'Lehrstuhl für BWL, insbes. Arbeit, Personal und Organisation' (Score: 0.97)
# Kein passender Match für 'Biomolekulare Festkörper-NMR-Spektroskopie' gefunden.
# Fuzzy Match gefunden: 'Pflanzengenetik CEPLAS' → 'Institut für Pflanzengenetik' (Score: 0.73)
# Kein passender Match für 'Trainingszentrum für ärztliche Fertigkeiten' gefunden.
# Fuzzy Match gefunden: 'Klinik für Gastroenterologie, Hepatologie und Infektiologie' → 'Klinik für Gastroenterologie, Hepatologie und Infektiologie' (Score: 1.00)
# Fuzzy Match gefunden: 'Klinik und Poliklinik für Psychiatrie und Psychotherapie der Heinrich-Heine-Universität Düsseldorf - LVR-Klinikum Düsseldorf' → 'Klinik und Poliklinik für Psychiatrie und Psychotherapie - Rheinische Kliniken Düsseldorf' (Score: 0.93)
# Fuzzy Match gefunden: 'Institut für Pharmakologie und Klinische Pharmakologie' → 'Institut für Pharmakologie' (Score: 0.90)
# Fuzzy Match gefunden: 'Poliklinik für Zahnerhaltung, Parodontologie und Endodontologie' → 'Poliklinik für Zahnerhaltung und Endodontologie' (Score: 0.96)
# Fuzzy Match gefunden: 'Anorganische Chemie u. Strukturchemie I' → 'Lehrstuhl für Bioanorganische Chemie' (Score: 0.73)
# Fuzzy Match gefunden: 'Institut für Anatomie I' → 'Institut für Anatomie I' (Score: 1.00)
# Fuzzy Match gefunden: 'Institut für Anatomie II' → 'Institut für Anatomie II' (Score: 1.00)
# Fuzzy Match gefunden: 'Physikalische Grundpraktika' → 'Arbeitsgruppe Physikalische Grundpraktika' (Score: 0.79)
# Fuzzy Match gefunden: 'Institut für Medien- und Kulturwissenschaft' → 'Institut für Medien- und Kulturwissenschaft' (Score: 1.00)
# Fuzzy Match gefunden: 'Neurologische Klinik' → 'Neurochirurgische Klinik' (Score: 0.84)
# Fuzzy Match gefunden: 'Wirtschaftswissenschaftliche Fakultät' → 'Wirtschaftswissenschaftliche Fakultät' (Score: 1.00)
# Fuzzy Match gefunden: 'Lehrstuhl für Betriebswirtschaftslehre, insbes. Sustainability Management' → 'Lehrstuhl für BWL, insb. Management' (Score: 0.81)
# Fuzzy Match gefunden: 'Lehrstuhl für Betriebswirtschaftslehre, insbes. Unternehmensprüfung und Controlling' → 'Lehrstuhl für BWL, insb. Accounting' (Score: 0.81)
# Fuzzy Match gefunden: 'Populationsgenetik' → 'Institut Populationsgenetik' (Score: 0.67)
# Kein passender Match für 'Studium Universale' gefunden.
# Fuzzy Match gefunden: 'Zentrum für Biochemie und Molekularbiologie' → 'Institut für Biochemie und Molekularbiologie I' (Score: 0.76)
# Kein passender Match für 'Volkswirtschaftslehre' gefunden.
# Fuzzy Match gefunden: 'Anglistik V - Anglophone Literaturen/Literaturübersetzen' → 'Anglistik V: Section Anglophone Literatures / Literary Translation' (Score: 0.89)
# Kein passender Match für 'Studiendekanat Medizinische Fakultät' gefunden.
# Fuzzy Match gefunden: 'Klinik für Endokrinologie und Diabetologie' → 'Klinik für Endokrinologie und Diabetologie' (Score: 1.00)
# Fuzzy Match gefunden: 'Institut für Geschichtswissenschaften' → 'Institut für Geschichtswissenschaft' (Score: 0.97)
# Fuzzy Match gefunden: 'Klinik für Kardiologie, Pneumologie und Angiologie' → 'Klinik für Kardiologie, Pneumologie und Angiologie' (Score: 1.00)
# Kein passender Match für 'Sinnesökologie' gefunden.
# Fuzzy Match gefunden: 'Lehrstuhl für Betriebswirtschaftslehre, insbes. Wirtschaftsprüfung' → 'Lehrstuhl für BWL, insbesondere Betriebswirtschaftliche Steuerlehre' (Score: 0.84)
# Fuzzy Match gefunden: 'Abteilung für Lasermassenspektrometrie' → 'Arbeitsgruppe Lasermassenspektroskopie' (Score: 0.77)
# Kein passender Match für 'Department Biologie' gefunden.
# Kein passender Match für 'Abt. IV: Theorie und Praxis (Schriftlichkeit)' gefunden.
# Fuzzy Match gefunden: 'Universitäts- und Landesbibliothek' → 'Universitäts- und Landesbibliothek' (Score: 1.00)
# Fuzzy Match gefunden: 'Anorganische Chemie u. Strukturchemie II' → 'Lehrstuhl für Bioanorganische Chemie' (Score: 0.71)
# Fuzzy Match gefunden: 'Abteilung für Politikwissenschaft' → 'Abteilung Soziologie' (Score: 0.76)
# Kein passender Match für 'Deutsch als Fremdsprache' gefunden.
# Fuzzy Match gefunden: 'Zentrum für Medizinische Mikrobiologie, Krankenhaushygiene und Virologie' → 'Institut für Medizinische Mikrobiologie und Krankenhaushygiene' (Score: 0.77)
# Fuzzy Match gefunden: 'Institut für Transplantationsdiagnostik und Zelltherapeutika' → 'Institut für Transplantationsdiagnostik und Zelltherapeutika (ITZ)' (Score: 0.90)
# Fuzzy Match gefunden: 'Institut für Medizinische Mikrobiologie und Krankenhaushygiene' → 'Institut für Medizinische Mikrobiologie und Krankenhaushygiene' (Score: 1.00)
# Fuzzy Match gefunden: 'Praktikumsbüro - Abteilung Soziologie' → 'Abteilung Soziologie' (Score: 0.72)
# Fuzzy Match gefunden: 'Lehrstuhl Festkörperphysik' → 'Lehrstuhl für Festkörperphysik' (Score: 0.96)
# Fuzzy Match gefunden: 'Abteilung für Allgemeine Sprachwissenschaft' → 'Abteilung für Allgemeine Sprachwissenschaft' (Score: 1.00)
# Kein passender Match für 'Center for Enterpreneurship (CEDUS)' gefunden.
# Fuzzy Match gefunden: 'Institut für Zoomorphologie, Zellbiologie und Parasitologie' → 'Institut für Zoologie und Organismische Interaktionen' (Score: 0.76)
# Fuzzy Match gefunden: 'Lehrstuhl für Betriebswirtschaftslehre, insbes. Entrepreneurship und Finanzierung' → 'Lehrstuhl für Betriebswirtschaftslehre, insb. Entrepreneurship und Finanzierung' (Score: 0.99)
# Fuzzy Match gefunden: 'Mathematisch-Naturwissenschaftliche Fakultät' → 'Wirtschaftswissenschaftliche Fakultät' (Score: 0.70)
# Fuzzy Match gefunden: 'Physikalische Chemie u. Elektrochemie II' → 'Institut für Physikalische Chemie' (Score: 0.68)
# Fuzzy Match gefunden: 'Institut für Laser- und Plasmaphysik' → 'Institut für Laser- und Plasmaphysik' (Score: 1.00)
# Fuzzy Match gefunden: 'SFB 1208 - Biochemie' → 'Lehrstuhl für Biochemie II' (Score: 0.70)
# Fuzzy Match gefunden: 'Physikalische Biologie' → 'Institut für Physikalische Biologie' (Score: 0.80)
# Fuzzy Match gefunden: 'Molekulare Ökophysiologie der Pflanzen' → 'Institut für Molekulare Ökophysiologie der Pflanzen' (Score: 0.84)
# Fuzzy Match gefunden: 'Soziologie I' → 'Lehrstuhl Soziologie I' (Score: 0.81)
# Fuzzy Match gefunden: 'Institut für Bioorganische Chemie' → 'Institut für Bioorganische Chemie (IBOC)' (Score: 0.90)
# Fuzzy Match gefunden: 'Entwicklungs- und Molekularbiologie der Pflanzen' → 'Institut für Entwicklungs- und Molekularbiologie der Pflanzen' (Score: 0.85)
# Fuzzy Match gefunden: 'Institut für Genetik' → 'Institut für Genetik' (Score: 1.00)
# Fuzzy Match gefunden: 'Anglistik VI - Comparative Literature' → 'Anglistik VI: Comparative Literatur' (Score: 0.92)
# Fuzzy Match gefunden: 'Mikrobiologie' → 'Institut für Mikrobiologie' (Score: 0.67)
# Fuzzy Match gefunden: 'Institut für Klinische Biochemie und Pathobiochemie' → 'Institut für Klinische Chemie und Laboratoriumsdiagnostik' (Score: 0.87)
# Fuzzy Match gefunden: 'Arbeitsgruppe Hochauflösende UV-Laserspektroskopie' → 'Arbeitsgruppe Hochauflösende UV-Laserspektroskopie' (Score: 1.00)
# Fuzzy Match gefunden: 'Institut für Modernes Japan' → 'Lehrstuhl Modernes Japan' (Score: 0.84)
# Fuzzy Match gefunden: 'Institut für Experimentalphysik - Bereich Prof. Görlitz' → 'Institut für Experimentalphysik' (Score: 0.80)
# Fuzzy Match gefunden: 'Anglistik I: Medieval Literatures and Historical Linguistics' → 'Anglistik I: Medieval English Studies and Historical Linguistics' (Score: 0.97)
# Fuzzy Match gefunden: 'Institut für Pharmazeutische Technologie' → 'Institut für Pharmazeutische Technologie und Biopharmazie' (Score: 0.92)
# Fuzzy Match gefunden: 'Institut für Organische Chemie und Makromolekulare Chemie' → 'Institut für Organische Chemie und Makromolekulare Chemie' (Score: 1.00)
# Fuzzy Match gefunden: 'Institut für Cytopathologie' → 'Institut für Pathologie' (Score: 0.82)
# Fuzzy Match gefunden: 'Klinik für Kardiovaskuläre Chirurgie' → 'Klinik für Herzchirurgie' (Score: 0.89)
# Fuzzy Match gefunden: 'Abteilung für Computerlinguistik' → 'Abteilung für Computerlinguistik' (Score: 1.00)
# Fuzzy Match gefunden: 'Zentrum für Medizinische Psychologie, Soziologie, Statistik und Allgemeinmedizin' → 'Institut für Statistik in der Medizin' (Score: 0.66)
# Fuzzy Match gefunden: 'Synthetische Biologie' → 'Institut für Synthetische Biologie' (Score: 0.70)
# Fuzzy Match gefunden: 'Institut für Romanistik' → 'Institut für Romanistik' (Score: 1.00)
# Fuzzy Match gefunden: 'Institut für Pharmazeutische und Medizinische Chemie' → 'Institut für Pharmazeutische und Medizinische Chemie' (Score: 1.00)
# Fuzzy Match gefunden: 'Kommunikations- und Medienwissenschaft II' → 'Abteilung Kommunikations- und Medienwissenschaft' (Score: 0.79)
# Fuzzy Match gefunden: 'Wissenschaftliche Einrichtung Informatik' → 'Abteilung für Informationswissenschaft' (Score: 0.67)
# Fuzzy Match gefunden: 'Klinik für Mund-, Kiefer- und Plastische Gesichtschirurgie' → 'Klinik für Mund-, Kiefer- und Plastische Gesichtschirurgie' (Score: 1.00)
# Fuzzy Match gefunden: 'Institut für Pharmazeutische Biologie' → 'Institut für Pharmazeutische Biologie und Biotechnologie' (Score: 0.91)
# Fuzzy Match gefunden: 'Biochemische Pflanzenphysiologie' → 'Institut für Biochemische Pflanzenphysiologie' (Score: 0.74)
# Kein passender Match für 'Gleichstellung' gefunden.
# Fuzzy Match gefunden: 'Zentrum für Physiologie' → 'Institut für Herz- und Kreislaufphysiologie' (Score: 0.73)
# Fuzzy Match gefunden: 'Politikwissenschaft IV' → 'Lehrstuhl Politikwissenschaft III' (Score: 0.73)
# Fuzzy Match gefunden: 'Politikwissenschaft II' → 'Lehrstuhl Politikwissenschaft II' (Score: 0.83)
# Fuzzy Match gefunden: 'Wissenschaftliche Einrichtung Chemie' → 'Institut für Physikalische Chemie' (Score: 0.72)
# Fuzzy Match gefunden: 'Nuklearmedizinische Klinik' → 'Neurochirurgische Klinik' (Score: 0.67)
# Fuzzy Match gefunden: 'Zentralinstitut für Klinische Chemie u. Laboratoriumsdiagnostik' → 'Institut für Klinische Chemie und Laboratoriumsdiagnostik' (Score: 0.84)
# Fuzzy Match gefunden: 'Institut für Herz- und Kreislaufphysiologie' → 'Institut für Herz- und Kreislaufphysiologie' (Score: 1.00)
# Kein passender Match für 'Abt. II: Neuere Dt. Literatur - Lehrstuhl Prof. Oesterhelt' gefunden.
# Kein passender Match für 'HeiCAD Heine Center of Artificial Intelligence and Data Science' gefunden.
# Fuzzy Match gefunden: 'Biochemie II: Biotransformation und Biokatalyse' → 'Lehrstuhl für Biochemie II' (Score: 0.65)
# Fuzzy Match gefunden: 'Lehrstuhl für Betriebswirtschaftslehre, insbes. Management' → 'Lehrstuhl für BWL, insb. Management' (Score: 0.95)
# Fuzzy Match gefunden: 'Institut für Toxikologie' → 'Institut für Toxikologie' (Score: 1.00)
# Fuzzy Match gefunden: 'CEPLAS' → 'CEPLAS Cluster of Excellence on Plant Sciences' (Score: 0.67)
# Fuzzy Match gefunden: 'Zentrum für Zahn-, Mund- und Kieferheilkunde - Westdeutsche Kieferklinik' → 'Klinik für Mund-, Kiefer- und Plastische Gesichtschirurgie' (Score: 0.72)
# Fuzzy Match gefunden: 'Photosyntheseforschung CEPLAS' → 'CEPLAS Cluster of Excellence on Plant Sciences' (Score: 0.73)
# Fuzzy Match gefunden: 'Dekanat Wirtschaftswiss. Fakultät' → 'Wirtschaftswissenschaftliche Fakultät' (Score: 0.77)
# Kein passender Match für 'Career Service' gefunden.
# Fuzzy Match gefunden: 'Neurochirugische Klinik' → 'Neurochirurgische Klinik' (Score: 0.97)
# Fuzzy Match gefunden: 'Klinik für Urologie' → 'Urologische Klinik' (Score: 0.89)
# Kein passender Match für 'Abt. II: Neuere Dt. Literatur - Lehrstuhl Prof. Nebrig' gefunden.
# Fuzzy Match gefunden: 'Philosophische Fakultät' → 'Juristische Fakultät' (Score: 0.75)
# Fuzzy Match gefunden: 'Abteilung VI Neuere Landesgeschichte u. Neueste Geschichte' → 'Lehrstuhl für Neuere und Neueste Geschichte' (Score: 0.70)
# Kein passender Match für 'Prorektorat für Hochschulmanagement und Internationales' gefunden.
# Fuzzy Match gefunden: 'Soziologie IV' → 'Lehrstuhl Soziologie III' (Score: 0.74)
# Fuzzy Match gefunden: 'Institut für Bio- und Geowissenschaften, IBG-2: Pflanzenwissenschaften' → 'Institut für Entwicklungs- und Molekularbiologie der Pflanzen' (Score: 0.78)
# Kein passender Match für 'Genetik' gefunden.
# Fuzzy Match gefunden: 'Abteilung für Bildungsforschung und Bildungsmanagement' → 'Abteilung für Bildungsforschung und Bildungsmanagement' (Score: 1.00)
# Fuzzy Match gefunden: 'Institut für Pathologie' → 'Institut für Pathologie' (Score: 1.00)
# Fuzzy Match gefunden: 'Institut für Allgemeinmedizin' → 'Institut für Allgemeinmedizin' (Score: 1.00)
# Fuzzy Match gefunden: 'Institut für Systemische Neurowissenschaften' → 'Institut für Systemische Neurowissenschaften' (Score: 1.00)
# Kein passender Match für 'Dekanat Medizinische Fakultät' gefunden.
# Fuzzy Match gefunden: 'Institut für Sozialwissenschaften' → 'Abteilung Soziologie' (Score: 0.74)
# Fuzzy Match gefunden: 'Wissenschaftliche Einrichtung Pharmazie' → 'Institut für Pharmazeutische und Medizinische Chemie' (Score: 0.75)
# Fuzzy Match gefunden: 'Institut für Linguistik' → 'Abteilung für Computerlinguistik' (Score: 0.73)
# Fuzzy Match gefunden: 'Kommunikations- und Medienwissenschaft III' → 'Abteilung Kommunikations- und Medienwissenschaft' (Score: 0.76)
# Fuzzy Match gefunden: 'Lehrstuhl für Kolloide und Nanooptik' → 'Lehrstuhl für nanoporöse und nanoskalierte Materialien' (Score: 0.72)
# Fuzzy Match gefunden: 'Poliklinik für Kieferorthopädie' → 'Poliklinik für Kieferorthopädie' (Score: 1.00)
# Fuzzy Match gefunden: 'Klinik für Allgemein- , Viszeral- und Kinderchirurgie' → 'Klinik für Allgemein-, Viszeral- und Kinderchirurgie' (Score: 0.99)
# Fuzzy Match gefunden: 'Selbständiger Funktionsbereich für Phoniatrie und Pädaudiologie' → 'Klinik für Phoniatrie und Pädaudiologie' (Score: 0.72)
# Fuzzy Match gefunden: 'Institut für Kunstgeschichte' → 'Institut für Kunstgeschichte' (Score: 1.00)
# Fuzzy Match gefunden: 'Entwicklungsgenetik' → 'Institut Entwicklungsgenetik' (Score: 0.69)
# Fuzzy Match gefunden: 'Mathematische Modellierung biologischer Systeme' → 'Institut Mathematische Modellierung biologischer Systeme' (Score: 0.78)
# Fuzzy Match gefunden: 'Institut für Mikrobiologie' → 'Institut für Mikrobiologie' (Score: 1.00)
# Fuzzy Match gefunden: 'Institut für Germanistik' → 'Institut für Romanistik' (Score: 0.77)
# Fuzzy Match gefunden: 'Abteilung V Geschichte und Kulturen Osteuropas' → 'Lehrstuhl für Geschichte und Kulturen Osteuropas' (Score: 0.77)
# Fuzzy Match gefunden: 'Institut für Neurobiologie' → 'Institut für Neurobiologie' (Score: 1.00)
# Fuzzy Match gefunden: 'Funktionelle Zellmorphologie' → 'Institut für Funktionelle Zellmorphologie' (Score: 0.74)
# Fuzzy Match gefunden: 'Physikalische Chemie u. Elektrochemie I' → 'Institut für Physikalische Chemie' (Score: 0.70)
# Fuzzy Match gefunden: 'Lehrstuhl für Statistics and Econometrics' → 'Lehrstuhl für Mathematische Statistik und Wahrscheinlichkeitstheorie' (Score: 0.79)
# Fuzzy Match gefunden: 'Lehrstuhl für Volkswirtschaftslehre, insbes. Monetäre Ökonomik' → 'Lehrstuhl für Volkswirtschaft, insb. Monetäre Ökonomik' (Score: 0.98)
# Fuzzy Match gefunden: 'Zentrum für Kinder- und Jugendmedizin - Kinderklinik' → 'Klinik für Allgemeine Pädiatrie, Neonatologie und Kinderkardiologie' (Score: 0.73)
# Fuzzy Match gefunden: 'Funktionelle Genomforschung der Mikroorganismen' → 'Institut für Funktionelle Genomforschung der Mikroorganismen' (Score: 0.74)
# Fuzzy Match gefunden: 'Institut für Philosophie' → 'Institut für Philosophie' (Score: 1.00)
# Fuzzy Match gefunden: 'Pflanzliche Zellbiologie und Biotechnologie' → 'Institut für Pflanzliche Zellbiologie und Biotechnologie' (Score: 0.82)
# Fuzzy Match gefunden: 'Institut für Medizinische Soziologie' → 'Institut für Arbeits-, Sozial- und Umweltmedizin' (Score: 0.77)
# Fuzzy Match gefunden: 'Institut für Physikalische Chemie und Elektrochemie' → 'Institut für Physikalische Chemie' (Score: 0.86)
# Kein passender Match für 'KUBUS (Praxis- und Berufsorientierung)' gefunden.
# Fuzzy Match gefunden: 'Stoffwechselphysiologie' → 'Institut für Stoffwechselphysiologie' (Score: 0.75)
# Fuzzy Match gefunden: 'Diagnostische und Interventionelle Radiologie' → 'Institut für Diagnostische und Interventionelle Radiologie' (Score: 0.85)
# Fuzzy Match gefunden: 'Klinisches Institut für Psychosomatische Medizin und Psychotherapie' → 'Klinisches Institut für Psychosomatische Medizin und Psychotherapie' (Score: 1.00)
# Fuzzy Match gefunden: 'Institut für Experimentelle Psychologie' → 'Abteilung Biologische Psychologie' (Score: 0.72)
# Fuzzy Match gefunden: 'C. & O. Vogt-Institut für Hirnforschung' → 'Cécile und Oskar Vogt-Institut für Hirnforschung' (Score: 0.82)
# Fuzzy Match gefunden: 'Mikrobielle Zellbiologie' → 'Institut für Mikrobielle Zellbiologie' (Score: 0.75)
# Fuzzy Match gefunden: 'Anglistik II: American Studies' → 'Anglistik II: Section American Studies' (Score: 0.96)
# Fuzzy Match gefunden: 'Institut für medizinische Biometrie und Bioinformatik' → 'Institut für medizinische Biometrie und Bioinformatik' (Score: 1.00)
# Kein passender Match für 'D 1.1 Studierendenservice' gefunden.
# Fuzzy Match gefunden: 'Anglistik III: English Language and Linguistics' → 'Anglistik III: English Language and Linguistics' (Score: 1.00)
# Fuzzy Match gefunden: 'Institut für Theoretische Chemie und Computerchemie' → 'Institut für Theoretische Chemie' (Score: 0.91)
# Fuzzy Match gefunden: 'Philosophische Fakultät allgemein' → 'Institut für Philosophie' (Score: 0.67)
# Fuzzy Match gefunden: 'Professur für Volkswirtschaftslehre, insbes. International Economics' → 'Lehrstuhl für Volkswirtschaft, insb. Monetäre Ökonomik' (Score: 0.79)
# Kein passender Match für 'Sprachenzentrum' gefunden.
# Kein passender Match für 'Hochschulverwaltung' gefunden.
# Kein passender Match für 'Europäische Expansion' gefunden.
# Kein passender Match für 'philGRAD' gefunden.
# Fuzzy Match gefunden: 'Institut für Jüdische Studien' → 'Institut für Jüdische Studien' (Score: 1.00)
# Fuzzy Match gefunden: 'Poliklinik für Zahnärztliche Chirurgie und Aufnahme' → 'Poliklinik für Zahnärztliche Chirurgie und Aufnahme' (Score: 1.00)
# Fuzzy Match gefunden: 'Politikwissenschaft I' → 'Lehrstuhl Politikwissenschaft II' (Score: 0.73)
# Fuzzy Match gefunden: 'Abteilung für Kommunikations- und Medienwissenschaft' → 'Abteilung Kommunikations- und Medienwissenschaft' (Score: 0.98)
# Fuzzy Match gefunden: 'Soziologie II' → 'Lehrstuhl Soziologie II' (Score: 0.81)
# Kein passender Match für 'IKM-Services' gefunden.
# Fuzzy Match gefunden: 'Institut für Klinische Neurowissenschaften und Medizinische Psychologie' → 'Institut für Klinische Neurowissenschaften und Medizinische Psychologie' (Score: 1.00)
# Fuzzy Match gefunden: 'Klinik für Nephrologie' → 'Klinik für Nephrologie' (Score: 1.00)
# Fuzzy Match gefunden: 'Lehrstuhl für Betriebswirtschaftslehre, insbes. Financial Accounting' → 'Lehrstuhl für BWL, insb. Accounting' (Score: 0.92)
# Fuzzy Match gefunden: 'Augenklinik' → 'Augenklinik' (Score: 1.00)
# Fuzzy Match gefunden: 'DICE (Duesseldorf Institute for Competition Economics)' → 'Düsseldorfer Institut für Wettbewerbsökonomie' (Score: 0.77)
# Kein passender Match für 'European Studies' gefunden.
# Fuzzy Match gefunden: 'Arbeitsgruppe Organische Photochemie' → 'Arbeitsgruppe Organische Photochemie' (Score: 1.00)
# Kein passender Match für 'Studierendenakademie' gefunden.
# Fuzzy Match gefunden: 'Lehrstuhl für Betriebswirtschaftslehre, insbes. Finanzdienstleistungen' → 'Lehrstuhl für BWL, insbesondere Finanzdienstleistungen' (Score: 0.96)

# %% [markdown]
# #### Erzeuge Applyer-Funktion
#
# Die Funktion `apply_matched_organisations` verwendet das zuvor erstellte Rekodierungs-Dictionary (`recode_dict`), um die ursprünglichen Organisationsnamen im Pandas-Data Frame (`org_df`) durch die gematchten Werte zu ersetzen.
#
# Zunächst wird eine innere Funktion `map_multiple_orgs` definiert, die für jeden Eintrag in der Spalte ausgeführt wird. Falls der Wert `NaN` ist, wird `None` zurückgegeben. Falls der Wert mehrere Organisationen enthält, werden diese anhand des Trennzeichens `";"` aufgeteilt und bereinigt. Für jede einzelne Organisation wird geprüft, ob sie im `recode_dict` vorhanden ist. Falls ja, wird der gematchte Wert ersetzt, ansonsten bleibt der Originalwert bestehen.
#
# Nach der Rekodierung werden leere Werte aus der Liste entfernt. Falls am Ende noch gültige Organisationen vorhanden sind, werden sie mit `"; "` wieder zusammengeführt. Falls keine gültigen Werte übrig bleiben, wird `None` zurückgegeben.
#
# Am Ende wird die gesamte Spalte mithilfe von `.apply()` transformiert, sodass alle Organisationsnamen durch ihre gematchten Werte ersetzt werden.

# %%
def apply_matched_organisations(org_df, recode_dict):
    """
    Wendet das zuvor berechnete Matching Dictionary auf die originale Spalte an,
    indem alle Organisationen innerhalb eines Eintrags korrekt ersetzt werden.

    :param org_df: Pandas Series mit den ursprünglichen Organisationen
    :param recode_dict: Dictionary mit den rekodierten Werten (Originalwert → gematchter Wert)
    :return: Pandas Series mit den rekodierten Organisationen
    """
    def map_multiple_orgs(org):
        if pd.isna(org):
            return None  # Fehlende Werte beibehalten

        org_list = [o.strip() for o in org.split(';')]  # Mehrere Organisationen aufteilen
        matched_list = [recode_dict.get(o, o) for o in org_list]  # Falls kein Match gefunden wird, Originalwert behalten
        matched_list = [m for m in matched_list if m]  # Leere Werte entfernen

        return "; ".join(matched_list) if matched_list else None  # Falls keine Matches, None zurückgeben

    return org_df.apply(map_multiple_orgs)

# %%
df["gerit_organisation"] = apply_matched_organisations(df_scraped["organisation_names_for_matching_back"], recode_dict)

# %% [markdown]
# # Rückspielen an urspürnglichen df
#
# Im folgenden werden die Ergebnisse schließlich an den `df` gematcht. Dies sind die Variablen `Score` sowie `match_type`, `gerit_organisation`.
#
# Zunächst wird dafür aus `recode_dict` ein neuer `DataFrame` (`recode_df`) erstellt, in dem die ursprünglichen Organisationsnamen als Index dienen und den gematchten GERIT-Wert enthalten. Der Index wird zurückgesetzt, sodass eine Spalte `"organisation_names_for_matching_back"` entsteht.
#
# Zusätzlich wird aus dem `matching_df` eine reduzierte Version (`matching_info`) erstellt, die nur die relevanten Spalten enthält: den ursprünglichen Wert (`"Ursprünglicher Wert"`), den Score und die Matching-Art (`"Matching-Art"`). Die Spalten werden dabei umbenannt, damit sie einheitlich zum späteren Merge passen.
#
# Danach wird der ursprüngliche `df` um diese neuen Informationen ergänzt. Dabei werden zuerst die gematchten Organisationsnamen (`recode_df`) und anschließend die Matching-Scores sowie die Matching-Art (`matching_info`) über einen `left join` anhand der Spalte `"organisation_names_for_matching_back"` hinzugefügt.
# Falls durch den Merge neue Spalten mit dem Suffix `"_new"` entstehen, werden die ursprünglichen Spalten (`"gerit_organisation"`, `"score"`, `"match_type"`) durch diese neuen Werte ersetzt. Falls eine neue Spalte existiert, wird sie in `df[col]` überschrieben und anschließend aus `df` entfernt, sodass keine unnötigen `_new`-Spalten übrig bleiben.

# %%
# DataFrame aus dem recode_dict erstellen
recode_df = pd.DataFrame.from_dict(recode_dict, orient="index", columns=["gerit_organisation"])
recode_df.reset_index(inplace=True)
recode_df.rename(columns={"index": "organisation_names_for_matching_back"}, inplace=True)

# Auch das Matching-DF nutzen, um Score und Matching-Art (umbenannt in match_type) anzufügen
matching_info = matching_df[['Ursprünglicher Wert', 'Score', 'Matching-Art']].drop_duplicates()
matching_info.rename(columns={'Ursprünglicher Wert': 'organisation_names_for_matching_back',
                              'Matching-Art': 'match_type'}, inplace=True)

# Merge mit df, dabei vorhandene Spalten ersetzen
df = df.merge(recode_df, on="organisation_names_for_matching_back", how="left", suffixes=("", "_new"))
df = df.merge(matching_info, on="organisation_names_for_matching_back", how="left", suffixes=("", "_new"))

# Existierende Spalten durch neue Werte ersetzen, falls vorhanden
for col in ["gerit_organisation", "score", "match_type"]:
    new_col = col + "_new"
    if new_col in df.columns:
        df[col] = df[new_col]
        df.drop(columns=[new_col], inplace=True)

# %%
df.columns
# Out:
# Index(['organisation_names_for_matching_back', 'organisation',
#        'organisation_alternativ', 'cleaned', 'cleaned_alternativ',
#        'scraped_ID', 'organisation_type_for_matching', 'no_courses',
#        'percent_courses', 'no_courses_from_2017', 'percent_courses_from_2017',
#        'matched', 'match_type', 'gerit_organisation', 'gerit_cleaned',
#        'gerit_studienbereich', 'gerit_faechergruppe', 'gerit_ID', 'name_rds',
#        'latest_scraped_semester_is', 'this_matching_is', 'Score'],
#       dtype='object')
